# %%
import pandas as pd

# %%
H_IRE=pd.read_csv(r"C:\Users\sarah\PycharmProjects\UCDPA_SarahBrien\homeless_ireland_2019-2021.csv")

# %%
print(H_IRE)
# Out:
#          Region  Total Adults  Male Adults  Female Adults  Adults Aged 18-24  \
# 0        Dublin          4175         2724           1451                485
# 1      Mid-East           329          218            111                 51
# 2      Midlands            66           36             30                 17
# 3      Mid-West           295          200             95                 29
# 4    North-East            85           66             19                 12
# ..          ...           ...          ...            ...                ...
# 283  North-East            89           68             21                 11
# 284  North-West            72           51             21                 18
# 285  South-East           169          124             45                 26
# 286  South-West           485          340            145                 57
# 287        West           248          146            102                 50
#
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
print(H_IRE.shape)
# Out:
# (288, 20)

# %%
H_IRE=pd.read_csv(r"C:\Users\sarah\PycharmProjects\UCDPA_SarahBrien\homeless_ireland_2019-2021.csv", index_col=0)

# %%
print(H_IRE.head)
# Out:
# <bound method NDFrame.head of             Total Adults  Male Adults  Female Adults  Adults Aged 18-24  \
# Region
# Dublin              4175         2724           1451                485
# Mid-East             329          218            111                 51
# Midlands              66           36             30                 17
# Mid-West             295          200             95                 29
# North-East            85           66             19                 12
# ...                  ...          ...            ...                ...
# North-East            89           68             21                 11
# North-West            72           51             21                 18
# South-East           169          124             45                 26
# South-West           485          340            145                 57
# West                 248          146            102                 50
#
# ...

# %%
missing_values_count = H_IRE.isnull().sum()

# %%
H_IRE.isnull().sum()
# Out:
# Total Adults                                                         0
# Male Adults                                                          0
# Female Adults                                                        0
# Adults Aged 18-24                                                    0
# Adults Aged 25-44                                                    0
# Adults Aged 45-64                                                    0
# Adults Aged 65+                                                      0
# Number of people who accessed Private Emergency Accommodation        0
# Number of people who accessed Supported Temporary Accommodation      0
# Number of people who accessed Temporary Emergency Accommodation      0
# Number of people who accessed Other Accommodation                    0
# Number of Families                                                   0
# Number of Adults in Families                                         0
# ...

# %%
print(missing_values_count[0:5])
# Out:
# Total Adults         0
# Male Adults          0
# Female Adults        0
# Adults Aged 18-24    0
# Adults Aged 25-44    0
# dtype: int64

# %%
H_IRE.loc[["Dublin"],["Total Adults"]]
# Out:
#         Total Adults
# Region
# Dublin          4175
# Dublin          4258
# Dublin          4129
# Dublin          4129
# Dublin          4304
# Dublin          4315
# Dublin          4087
# Dublin          4401
# Dublin          4054
# Dublin          4367
# Dublin          4356
# Dublin          4300
# Dublin          4220
# Dublin          4312
# Dublin          4287
# Dublin          4370
# Dublin          4432
# Dublin          4534
# Dublin          4509
# Dublin          4509
# Dublin          4600
# Dublin          4515
# Dublin          4266
# Dublin          4164
# Dublin          4173
# Dublin          4069
# Dublin          4188
# Dublin          4204
# Dublin          4251
# Dublin          4297
# Dublin          4243
# Dublin          4158

# %%
H_IRE.iloc[[1,2,3],[3]]
# Out:
#           Adults Aged 18-24
# Region
# Mid-East                 51
# Midlands                 17
# Mid-West                 29

# %%
Region_Grouped = H_IRE.groupby(["Total Adults"]).mean()

# %%
print(Region_Grouped)
# Out:
#               Male Adults  Female Adults  Adults Aged 18-24  \
# Total Adults
# 48                   33.0           15.0                7.0
# 50                   36.0           14.0                7.0
# 51                   35.0           16.0               12.0
# 52                   35.0           17.0               13.0
# 54                   40.0           14.0                8.0
# ...                   ...            ...                ...
# 4432               2875.0         1557.0              769.0
# 4509               2636.0         1873.0              557.0
# 4515               2773.0         1742.0              524.0
# 4534               2658.0         1876.0              583.0
# 4600               2773.0         1827.0              577.0
#
#               Adults Aged 25-44  Adults Aged 45-64  Adults Aged 65+  \
# Total Adults
# 48                         28.0               11.0              2.0
# 50                         29.0               12.0              2.0
# ...

# %%
#importing second data set residential properites in ireland 2020
PPR=pd.read_csv(r"C:\Users\sarah\PycharmProjects\UCDPA_SarahBrien\PPR-2020.csv")

# %%
print(PPR.head())
# Out:
#   Date of Sale (dd/mm/yyyy)  \
# 0                01/01/2020
# 1                01/01/2020
# 2                01/01/2020
# 3                01/01/2020
# 4                02/01/2020
#
#                                              Address Postal Code     County  \
# 0  APT 1 LEE HOUSE, STRAND LANE  THE QUAY, CARRIC...         NaN  Tipperary
# 1  Lands at Cliffor'd Field, Treanoughtragh, Glen...         NaN      Kerry
# 2                   ROSSACOOSANE, TEMPLENOE, KENMARE         NaN      Kerry
# 3           Site 4, Clifford's Field, Treanoughtragh         NaN      Kerry
# 4          105 DONAGHMORE, THE ANCHORAGE, BETTYSTOWN         NaN      Meath
#
#      Price (�) Not Full Market Price VAT Exclusive  \
# 0  �120,000.00                    No            No
# 1  �248,681.00                    No           Yes
# 2  �450,000.00                    No            No
# 3  �286,950.00                    No           Yes
# 4  �125,000.00                    No            No
#
# ...

# %%
#merging
H_IREPPR = pd.merge(H_IRE, PPR, how='inner', left_on = 'Region', right_on = 'County')

# %%
print(H_IREPPR.head())
# Out:
#    Total Adults  Male Adults  Female Adults  Adults Aged 18-24  \
# 0          4175         2724           1451                485
# 1          4175         2724           1451                485
# 2          4175         2724           1451                485
# 3          4175         2724           1451                485
# 4          4175         2724           1451                485
#
#    Adults Aged 25-44  Adults Aged 45-64  Adults Aged 65+  \
# 0               2397               1225               68
# 1               2397               1225               68
# 2               2397               1225               68
# 3               2397               1225               68
# 4               2397               1225               68
#
#    Number of people who accessed Private Emergency Accommodation  \
# 0                                               2372
# 1                                               2372
# 2                                               2372
# ...

# %%
cleaned_data = H_IREPPR.fillna(0)

# %%
print(cleaned_data.head())
# Out:
#    Total Adults  Male Adults  Female Adults  Adults Aged 18-24  \
# 0          4175         2724           1451                485
# 1          4175         2724           1451                485
# 2          4175         2724           1451                485
# 3          4175         2724           1451                485
# 4          4175         2724           1451                485
#
#    Adults Aged 25-44  Adults Aged 45-64  Adults Aged 65+  \
# 0               2397               1225               68
# 1               2397               1225               68
# 2               2397               1225               68
# 3               2397               1225               68
# 4               2397               1225               68
#
#    Number of people who accessed Private Emergency Accommodation  \
# 0                                               2372
# 1                                               2372
# 2                                               2372
# ...
